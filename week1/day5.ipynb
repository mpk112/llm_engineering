# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/08/06/outsmart/',
#  'https://edwarddonner.com/2024/08/06/outsmart/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/08/06/outsmart/
# https://edwarddonner.com/2024/08/06/outsmart/
# https://edwarddonner.com/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/blog/smolagents',
#  '/microsoft/phi-4',
#  '/hexgrad/Kokoro-82M',
#  '/deepseek-ai/DeepSeek-V3',
#  '/NovaSky-AI/Sky-T1-32B-Preview',
#  '/black-forest-labs/FLUX.1-dev',
#  '/models',
#  '/spaces/JeffreyXiang/TRELLIS',
#  '/spaces/lllyasviel/iclight-v2',
#  '/spaces/hexgrad/Kokoro-TTS',
#  '/spaces/reach-vb/2024-ai-timeline',
#  '/spaces/fffiloni/LatentSync',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/DAMO-NLP-SG/multimodal_textbook',
#  '/datasets/cfahlgren1/react-code-instructions',
#  '/datasets/NovaSky-AI/Sky-T1_data_17k',
#  '/datasets/PowerInfer/QWQ-LONGCOT-500K',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/peft',
#  '/docs/transformers.js',
#  '/docs/timm',
#  '/docs/trl',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord',
#  'https://www.zhihu.com/org/huggingface',
#  'https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/blog/chinese-language-blog/wechat.jpg']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# smolagents - a smol library to build great agents
# Use models from the HF Hub in LM Studio
# Use Ollama with GGUF Models from the HF Hub
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Trending on
# this week
# Models
# microsoft/phi-4
# Updated
# 5 days ago
# •
# 49.9k
# •
# 1.12k
# hexgrad/Kokoro-82M
# Updated
# 7 days ago
# •
# 11.4k
# •
# 911
# deepseek-ai/DeepSeek-V3
# Updated
# 15 days ago
# •
# 115k
# •
# 1.76k
# NovaSky-AI/Sky-T1-32B-Preview
# Updated
# about 9 hours ago
# •
# 652
# •
# 220
# black-forest-labs/FLUX.1-dev
# Updated
# Aug 16, 2024
# •
# 1.26M
# •
# 7.96k
# Browse 400k+ models
# Spaces
# Running
# on
# Zero
# 2.91k
# 🏢
# TRELLIS
# Scalable and Versatile 3D Generation from images
# Running
# on
# Zero
# 1.57k
# 📈
# IC Light V2
# Running
# on
# Zero
# 390
# ❤️
# Kokoro TTS
# Now in 5 languages!
# Running
# 357
# 📈
# 2024 AI Timeline
# Running
# on
# L4
# 228
# 👄
# LatentSync
# Audio Conditioned LipSync with Latent Diffusion Models
# Browse 150k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# 8 days ago
# •
# 5.12k
# •
# 6.84k
# DAMO-NLP-SG/multimodal_textbook
# Updated
# 2 days ago
# •
# 5.31k
# •
# 89
# cfahlgren1/react-code-instructions
# Updated
# about 1 hour ago
# •
# 678
# •
# 112
# NovaSky-AI/Sky-T1_data_17k
# Updated
# about 9 hours ago
# •
# 278
# •
# 47
# PowerInfer/QWQ-LONGCOT-500K
# Updated
# 18 days ago
# •
# 838
# •
# 101
# Browse 100k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 378 models
# •
# 1.89k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.1k followers
# Amazon Web Services
# company
# •
# 21 models
# •
# 2.52k followers
# Google
# company
# •
# 913 models
# •
# 6.45k followers
# Intel
# company
# •
# 217 models
# •
# 2.14k followers
# Microsoft
# company
# •
# 353 models
# •
# 7.13k followers
# Grammarly
# company
# •
# 10 models
# •
# 109 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 197 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 137,511
# State-of-the-art ML for Pytorch, TensorFlow, and JAX.
# Diffusers
# 27,093
# State-of-the-art diffusion models for image and audio generation in PyTorch.
# Safetensors
# 3,002
# Simple, safe way to store and distribute neural networks weights safely and quickly.
# Hub Python Library
# 2,220
# Client library for the HF Hub: manage repositories from your Python runtime.
# Tokenizers
# 9,247
# Fast tokenizers, optimized for both research and production.
# PEFT
# 16,952
# Parameter efficient finetuning methods for large models.
# Transformers.js
# 12,572
# State-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.
# timm
# 32,873
# State-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities.
# TRL
# 10,587
# Train transformer language models with reinforcement learning.
# Datasets
# 19,461
# Access and share datasets for computer vision, audio, and NLP tasks.
# Text Generation Inference
# 9,578
# Toolkit to serve Large Language Models.
# Accelerate
# 8,171
# Easily train and use PyTorch models with multi-GPU, TPU, mixed-precision.
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# about page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# smolagents - a smol library to build great agents
# Use models from the HF Hub in LM Studio
# Use Ollama with GGUF Models from the HF Hub
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Trending on
# this week
# Models
# microsoft/phi-4
# Updated
# 5 days ago
# •
# 49.9k
# •
# 1.12k
# hexgrad/Kokoro-82M
# Updated
# 7 days ago
# •
# 11.4k
# •
# 911
# deepseek-ai/DeepSeek-V3
# Updated
# 15 days ago
# •
# 115k
# •
# 1.76k
# NovaSky-AI/Sky-T1-32B-Preview
# Updated
# about 9 hours ago
# •
# 652
# •
# 220
# black-forest-labs/FLUX.1-dev
# Updated
# Aug 16, 2024
# •
# 1.26M
# •
# 7.96k
# Browse 400k+ models
# Spaces
# Running
# on
# Zero
# 2.91k
# 🏢
# TRELLIS
# Scalable and Versatile 3D Generation from images
# Running
# on
# Zero
# 1.57k
# 📈
# IC Light V2
# Running
# on
# Zero
# 390
# ❤️
# Kokoro TTS
# Now in 5 languages!
# Running
# 357
# 📈
# 2024 AI Timeline
# Running
# on
# L4
# 228
# 👄
# LatentSync
# Audio Conditioned LipSync with Latent Diffusion Models
# Browse 150k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# 8 days ago
# •
# 5.12k
# •
# 6.84k
# DAMO-NLP-SG/multimodal_textbook
# Updated
# 2 days ago
# •
# 5.31k
# •
# 89
# cfahlgren1/react-code-instructions
# Updated
# about 1 hour ago
# •
# 678
# •
# 112
# NovaSky-AI/Sky-T1_data_17k
# Updated
# about 9 hours ago
# •
# 278
# •
# 47
# PowerInfer/QWQ-LONGCOT-500K
# Updated
# 18 days ago
# •
# 838
# •
# 101
# Browse 100k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 378 models
# •
# 1.89k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.1k followers
# Amazon Web Services
# company
# •
# 21 models
# •
# 2.52k followers
# Google
# company
# •
# 913 models
# •
# 6.45k followers
# Intel
# company
# •
# 217 models
# •
# 2.14k followers
# Microsoft
# company
# •
# 353 models
# •
# 7.13k followers
# Grammarly
# company
# •
# 10 models
# •
# 109 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 197 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 137,511
# State-of-the-art ML for Pytorch, TensorFlow, and JAX.
# Diffusers
# 27,093
# State-of-the-art diffusion models for image and audio generation in PyTorch.
# Safetensors
# 3,002
# Simple, safe way to store and distribute neural networks weights safely and quickly.
# Hub Python Library
# 2,220
# Client library for the HF Hub: manage repositories from your Python runtime.
# Tokenizers
# 9,247
# Fast tokenizers, optimized for both research and production.
# PEFT
# 16,952
# Parameter efficient finetuning methods for large models.
# Transformers.js
# 12,572
# State-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.
# timm
# 32,873
# State-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities.
# TRL
# 10,587
# Train transformer language models with reinforcement learning.
# Datasets
# 19,461
# Access and share datasets for computer vision, audio, and NLP tasks.
# Text Generation Inference
# 9,578
# Toolkit to serve Large Language Models.
# Accelerate
# 8,171
# Easily train and use PyTorch models with multi-GPU, TPU, mixed-precision.
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# company page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU for Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 262 models
# •
# 9.85k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 270 followers
# Cerebras
# Enterprise
# company
# •
# 17 models
# •
# 433 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 197 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 8 models
# •
# 95 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 367 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 64 models
# •
# 1.12k followers
# Chegg Inc
# Enterprise
# company
# •
# 78 followers
# Liberty Mutual
# Enterprise
# company
# •
# 43 followers
# Arcee AI
# Enterprise
# company
# •
# 130 models
# •
# 304 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 86 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 37 followers
# Widn AI
# Enterprise
# company
# •
# 28 followers
# BRIA AI
# Enterprise
# company
# •
# 29 models
# •
# 1.7k followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 18.9k followers
# Orange
# Enterprise
# company
# •
# 4 models
# •
# 155 followers
# Arm
# Enterprise
# company
# •
# 124 followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.1k followers
# Fidelity Investments
# Enterprise
# company
# •
# 119 followers
# Jusbrasil
# Enterprise
# company
# •
# 77 followers
# Aledade Inc
# Enterprise
# company
# •
# 55 followers
# Stability AI
# Enterprise
# company
# •
# 98 models
# •
# 11.4k followers
# creditkarma
# Enterprise
# company
# •
# 37 followers
# Nutanix
# Enterprise
# company
# •
# 246 models
# •
# 40 followers
# Kakao Corp.
# Enterprise
# company
# •
# 42 followers
# Gsk-tech
# Enterprise
# company
# •
# 33 followers
# Adyen
# Enterprise
# company
# •
# 37 followers
# Hover External
# Enterprise
# company
# •
# 26 followers
# Shopify
# Enterprise
# company
# •
# 380 followers
# Together
# Enterprise
# company
# •
# 29 models
# •
# 479 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 111 followers
# Bloomberg
# Enterprise
# company
# •
# 2 models
# •
# 139 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 117 followers
# Mistral AI_
# Enterprise
# company
# •
# 21 models
# •
# 3.85k followers
# IBM Granite
# Enterprise
# company
# •
# 70 models
# •
# 804 followers
# Virtusa Corporation
# Enterprise
# company
# •
# 54 followers
# HiddenLayer
# Enterprise
# company
# •
# 52 followers
# Ekimetrics
# Enterprise
# company
# •
# 48 followers
# Gretel.ai
# Enterprise
# company
# •
# 8 models
# •
# 82 followers
# BCG X
# Enterprise
# company
# •
# 30 followers
# Qualcomm
# Enterprise
# company
# •
# 153 models
# •
# 382 followers
# Liquid AI
# Enterprise
# company
# •
# 91 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# Visual Document Retrieval Goes Multilingual
# By
# marco
# January 10, 2025
# guest
# •
# 48
# Community Articles
# view all
# Building a Real-Time Video Chat with Gemini 2.0, Gradio, and WebRTC 👀👂
# By
# freddyaboulton
# •
# 12 minutes ago
# My first blog
# By
# mypal-life
# •
# about 2 hours ago
# Embodied AI == Unlimited Training Data
# By
# kenhktsui
# •
# about 3 hours ago
# •
# 1
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# 1 day ago
# •
# 17
# A Multi-Agent Ecosystem for Autonomous AI
# By
# adityagaharawar
# •
# 1 day ago
# Exploring Hard Negative Mining with NV-Retriever in Korean Financial Text
# By
# Albertmade
# •
# 1 day ago
# •
# 7
# 🦸🏻#7: From Agentic AI to Physical AI
# By
# Kseniase
# •
# 2 days ago
# •
# 4
# **N-Queens Problem Based Monte Carlo Algorithm**
# By
# prithivMLmods
# •
# 2 days ago
# •
# 7
# 🐺🐦‍⬛ LLM Comparison/Test: Phi-4, Qwen2 VL 72B Instruct, Aya Expanse 32B in my updated MMLU-Pro CS benchmark
# By
# wolfram
# •
# 3 days ago
# •
# 2
# Python Is All You Need? Introducing Dria-Agent-α
# By
# andthattoo
# •
# 3 days ago
# •
# 7
# Search the Web with AI
# By
# as-cle-bert
# •
# 3 days ago
# •
# 2
# TerjamaBench: A Cultural Benchmark for English-Darija Machine Translation
# By
# imomayiz
# •
# 3 days ago
# •
# 17
# Beyond Image Preferences - Rich Human Feedback for Text-to-Image Generation
# By
# RapidataAI
# •
# 4 days ago
# •
# 13
# 🅰️ℹ️ 1️⃣0️⃣1️⃣ **What is HtmlRAG, Multimodal RAG and Agentic RAG?**
# By
# Kseniase
# •
# 4 days ago
# •
# 4
# AI-Powered Content Creation for Release Notes Using KaibanJS
# By
# darielnoel
# •
# 6 days ago
# Synthetic Data Generation with FastData and Hugging Face
# By
# asoria
# •
# 6 days ago
# •
# 12
# Crowd-sourced Open Preference Dataset for Text-to-Image Generation
# By
# RapidataAI
# •
# 6 days ago
# •
# 17
# Accelerating Language Model Inference with Mixture of Attentions
# By
# hba123
# •
# 6 days ago
# •
# 24
# 🌁#82: AI and ML in Real Life
# By
# Kseniase
# •
# 6 days ago
# •
# 15
# Announcing NVIDIA Cosmos World Foundation Models
# By
# mingyuliutw
# •
# 7 days ago
# •
# 21
# CO₂ Emissions and Models Performance: Insights from the Open LLM Leaderboard
# By
# alozowski
# January 9, 2025
# •
# 11
# Introducing smolagents: simple agents that write actions in code.
# By
# m-ric
# December 31, 2024
# •
# 431
# Visualize and understand GPU memory in PyTorch
# By
# qgallouedec
# December 24, 2024
# •
# 153
# Controlling Language Model Generation with NVIDIA's LogitsProcessorZoo
# By
# ariG23498
# December 23, 2024
# •
# 33
# Evaluating Audio Reasoning with Big Bench Audio
# By
# mhillsmith
# December 20, 2024
# guest
# •
# 16
# Finally, a Replacement for BERT: Introducing ModernBERT
# By
# bwarner
# December 19, 2024
# guest
# •
# 475
# Bamba: Inference-Efficient Hybrid Mamba2 Model
# By
# Linsong-C
# December 18, 2024
# guest
# •
# 39
# Welcome the Falcon 3 Family of Open Models!
# By
# FalconLLM
# December 17, 2024
# •
# 114
# Benchmarking Language Model Performance on 5th Gen Xeon at GCP
# By
# MatrixYao
# December 17, 2024
# •
# 3
# Introducing the Synthetic Data Generator - Build Datasets with Natural Language
# By
# davidberenstein1957
# December 16, 2024
# •
# 78
# LeMaterial: an open source initiative to accelerate materials discovery and research
# By
# AlexDuvalinho
# December 10, 2024
# guest
# •
# 35
# Hugging Face models in Amazon Bedrock
# By
# pagezyhf
# December 9, 2024
# •
# 10
# Open Preference Dataset for Text-to-Image Generation by the 🤗 Community
# By
# davidberenstein1957
# December 9, 2024
# •
# 50
# Welcome PaliGemma 2 – New vision language models by Google
# By
# merve
# December 5, 2024
# •
# 125
# Previous
# 1
# 2
# 3
# ...
# 37
# Next
# Community Articles
# view all
# Building a Real-Time Video Chat with Gemini 2.0, Gradio, and WebRTC 👀👂
# By
# freddyaboulton
# •
# 12 minutes ago
# My first blog
# By
# mypal-life
# •
# about 2 hours ago
# Embodied AI == Unlimited Training Data
# By
# kenhktsui
# •
# about 3 hours ago
# •
# 1
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# 1 day ago
# •
# 17
# A Multi-Agent Ecosystem for Autonomous AI
# By
# adityagaharawar
# •
# 1 day ago
# Exploring Hard Negative Mining with NV-Retriever in Korean Financial Text
# By
# Albertmade
# •
# 1 day ago
# •
# 7
# 🦸🏻#7: From Agentic AI to Physical AI
# By
# Kseniase
# •
# 2 days ago
# •
# 4
# **N-Queens Problem Based Monte Carlo Algorithm**
# By
# prithivMLmods
# •
# 2 days ago
# •
# 7
# 🐺🐦‍⬛ LLM Comparison/Test: Phi-4, Qwen2 VL 72B Instruct, Aya Expanse 32B in my updated MMLU-Pro CS benchmark
# By
# wolfram
# •
# 3 days ago
# •
# 2
# Python Is All You Need? Introducing Dria-Agent-α
# By
# andthattoo
# •
# 3 days ago
# •
# 7
# Search the Web with AI
# By
# as-cle-bert
# •
# 3 days ago
# •
# 2
# TerjamaBench: A Cultural Benchmark for English-Darija Machine Translation
# By
# imomayiz
# •
# 3 days ago
# •
# 17
# Beyond Image Preferences - Rich Human Feedback for Text-to-Image Generation
# By
# RapidataAI
# •
# 4 days ago
# •
# 13
# 🅰️ℹ️ 1️⃣0️⃣1️⃣ **What is HtmlRAG, Multimodal RAG and Agentic RAG?**
# By
# Kseniase
# •
# 4 days ago
# •
# 4
# AI-Powered Content Creation for Release Notes Using KaibanJS
# By
# darielnoel
# •
# 6 days ago
# Synthetic Data Generation with FastData and Hugging Face
# By
# asoria
# •
# 6 days ago
# •
# 12
# Crowd-sourced Open Preference Dataset for Text-to-Image Generation
# By
# RapidataAI
# •
# 6 days ago
# •
# 17
# Accelerating Language Model Inference with Mixture of Attentions
# By
# hba123
# •
# 6 days ago
# •
# 24
# 🌁#82: AI and ML in Real Life
# By
# Kseniase
# •
# 6 days ago
# •
# 15
# Announcing NVIDIA Cosmos World Foundation Models
# By
# mingyuliutw
# •
# 7 days ago
# •
# 21
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Dataset preview rendering with NULL
# 🤗Datasets
# 0
# 3
# January 13, 2025
# How to enter longer prompt words
# 🧨 Diffusers
# 1
# 8
# January 13, 2025
# Portable, lightweight hugging face model inference locally
# Beginners
# 3
# 5
# January 13, 2025
# Combining pyannote with whisper to get a given speaker's text in Hebrew
# Beginners
# 0
# 3
# January 13, 2025
# Understanding Encoder-Decoder Transformer Architecture in Image Captioning
# Beginners
# 0
# 4
# January 13, 2025
# Darshan Hiranandani : Implementing Website Search Functionality for Custom Chatbots Using RAG
# Beginners
# 1
# 8
# January 13, 2025
# How to ban or report spam account on hf?
# Beginners
# 1
# 5
# January 13, 2025
# Improving Key-Value Pair Extraction with LayoutLM and LiLT on Custom OCR Dataset
# Research
# 0
# 5
# January 13, 2025
# Qwen Not work anymore
# 🤗Transformers
# 1
# 11
# January 13, 2025
# No matter what I do the HF…
# 🤗Transformers
# 2
# 15
# January 13, 2025
# Workload evicted, storage limit exceeded (100G)
# Models
# 2
# 41
# January 13, 2025
# Is there such thing as getting masks length and width?
# Beginners
# 6
# 10
# January 13, 2025
# New Framework smolagents
# Beginners
# 1
# 10
# January 13, 2025
# Expected `tensors` and `new_tensors` to have the same type but found <class 'tuple'> and <class 'torch.Tensor'>
# 🤗Transformers
# 2
# 9
# January 12, 2025
# Continuing Pre Training from Model Checkpoint
# Models
# 12
# 36723
# January 13, 2025
# ValueError: Image path is None/Invalid Imagedata dictionary
# Spaces
# 0
# 8
# January 13, 2025
# Continuous training of google-bert/bert-base-uncased
# Beginners
# 1
# 79
# January 13, 2025
# Denied llama 3.2
# Beginners
# 1
# 20
# January 13, 2025
# Access to LlaMa 2 denied
# Beginners
# 2
# 51
# January 12, 2025
# Multi-Head Attention in Transformers
# Models
# 1
# 17
# January 12, 2025
# Model for evaluation of scanned survey data
# Beginners
# 4
# 14
# January 13, 2025
# Spaces force push getting "Repository storage limit reached"
# Spaces
# 8
# 177
# January 12, 2025
# Gated Repo Access
# Models
# 2
# 15
# January 12, 2025
# Supported models
# 🤗Optimum
# 4
# 48
# January 10, 2025
# How to a build a dataset using s3 uris
# 🤗Datasets
# 5
# 427
# January 13, 2025
# LoadDataSet pyarrow.lib.ArrowCapacityError
# 🤗Datasets
# 6
# 17
# January 12, 2025
# What is CV_8UC1 and why do I need the image to be that to make a contour out of it?
# Beginners
# 22
# 60
# January 7, 2025
# How to Find the Admin of My Hugging Face Organization for Model Access?
# Beginners
# 1
# 9
# January 12, 2025
# How to prevent catastrophic forgetting in fine tuned large language models?
# Beginners
# 3
# 27
# January 11, 2025
# Huggingface dataset install
# 🤗Datasets
# 12
# 914
# January 8, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# github page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# White papers, Ebooks, Webinars
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# Advanced Security
# Enterprise-grade security features
# GitHub Copilot
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 41.1k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 138k
# 27.5k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 27.1k
# 5.6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 19.5k
# 2.7k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 17k
# 1.7k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.2k
# 1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.7k
# 486
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 279 repositories
# optimum-tpu
# Public
# Google TPU optimizations for transformers models
# huggingface/optimum-tpu’s past year of commit activity
# Python
# 86
# Apache-2.0
# 22
# 5
# 2
# Updated
# Jan 13, 2025
# hf-endpoints-documentation
# Public
# huggingface/hf-endpoints-documentation’s past year of commit activity
# 16
# 10
# 2
# 3
# Updated
# Jan 13, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 137,513
# Apache-2.0
# 27,536
# 992
# (2 issues need help)
# 525
# Updated
# Jan 13, 2025
# candle
# Public
# Minimalist ML framework for Rust
# huggingface/candle’s past year of commit activity
# Rust
# 16,277
# Apache-2.0
# 1,004
# 352
# (5 issues need help)
# 87
# Updated
# Jan 13, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 8,183
# Apache-2.0
# 840
# 86
# 83
# Updated
# Jan 13, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 27,093
# Apache-2.0
# 5,555
# 390
# (9 issues need help)
# 174
# Updated
# Jan 13, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 1,463
# MIT
# 263
# 102
# (5 issues need help)
# 46
# Updated
# Jan 13, 2025
# smolagents
# Public
# 🤗 smolagents: a barebones library for agents. Agents write python code to call tools and orchestrate other agents.
# huggingface/smolagents’s past year of commit activity
# Python
# 4,889
# Apache-2.0
# 410
# 41
# 11
# Updated
# Jan 13, 2025
# meshgen
# Public
# A blender addon for generating meshes with AI
# huggingface/meshgen’s past year of commit activity
# Python
# 427
# MIT
# 24
# 6
# 0
# Updated
# Jan 13, 2025
# blog
# Public
# Public repo for HF blog posts
# huggingface/blog’s past year of commit activity
# Jupyter Notebook
# 2,517
# 785
# 151
# (1 issue needs help)
# 71
# Updated
# Jan 13, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# deep-learning
# transformers
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# twitter page
# Webpage Title:
# x.com
# Webpage Contents:
#
#
#
#
# linkedin page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 485 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian@🤗 | Championing Open Science & Machine Learning
# 20m
# Report this post
# Introducing scandi-fine-web-cleaner the first model trained on FineWeb-C community annotations! 🎯
#
# FineWeb2 is a massive multilingual dataset for pre-training language models. Like any web-scale dataset, it contains low-quality content. How can we improve it?
#
# Over the past months, an amazing community of 400+ annotators has been labelling content quality (using
# Argilla
# ) across 23 languages through the FineWeb-C initiative.
#
# Today, I'm happy to share the first classifier trained on this data.
#
# 🔍 What we've built:
#
# - A lightweight classifier that efficiently removes low-quality content
# - 90%+ precision demonstrated on Danish & Swedish
# - Can process the 43M+ documents in Danish FineWeb2 with minimal compute
#
# Models are open on the
# Hugging Face
# Hub:
# https://lnkd.in/ePSKg6ii
# 🌍 Why this matters: The approach can be reproduced for any of the 23 languages in FineWeb-C. We can improve training data quality at scale without massive compute resources by starting with community annotations and training small, efficient classifiers.
#
# Want to build a classifier for your language? Check out the full blog post with code examples and implementation details:
# https://lnkd.in/eMfv3PAx
# .
# Hygge Data - Cleaning Web Scale Data using small classifiers
# danielvanstrien.xyz
# 7
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 49,474 followers
# 6h
# Edited
# Report this post
# 🤖 Ultravox is a multimodal LLM that processes text and speech.
# 🤯 Time-to-first-token (TTFT) is ~150ms. Tokens-per-second rate of ~60 using a Llama 3.1 8B backbone.
#
# > Takes in audio and emits streaming text.
# > Processes text and speech directly, eliminating the need for separate ASR.
# > Project is trending on GitHub at the moment!🔥
# > You can deploy
# Fixie.ai
# 's Ultravox MLLM using their Gradio web UI linked on the project readme. Ultravox can also be found on
# Hugging Face
# . Kudos to
# Freddy Boulton
# for all the effort with gradio-webrtc and demo.
# 125
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 49,474 followers
# 7h
# Report this post
# 🔥Generate about an hour of audio per minute on the Kokoro-82M TTS model, with exceptional quality. APACHE 2.0 licensed. Gradio app is on
# Hugging Face
# :
# https://lnkd.in/gfzD_ZZF
# Vaibhav Srivastav
# GPU poor @ Hugging Face
# 2d
# NEW: Kokoro 82M - APACHE 2.0 licensed, Text to Speech model, trained on < 100 hours of audio 🔥
# 30
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 49,474 followers
# 10h
# Edited
# Report this post
# SVFR is a framework for Face Video Restoration!
# Supports Blind Face Restoration, Colorization, Inpainting, and their combinations within one system 🤩 Learn more about the project from the links in our comment.
# …more
# 83
# 11 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aymeric Roucher
# Building agents @ Hugging Face 🤗 | Polytechnique - Cambridge
# 2d
# Edited
# Report this post
# I've just released a new version of 𝘀𝗺𝗼𝗹𝗮𝗴𝗲𝗻𝘁𝘀: 1.2.0! 🥳
#
# Amongst other cool things like halving all loading times, there's Hugging Chat compatibility for all tools:
# -> after calling Tool.push_to_hub() on a tool to upload it as a Space, you can now use it in HuggingChat!
# …more
# 277
# 10 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 49,474 followers
# 3d
# Edited
# Report this post
# SPAR3D app is now up on
# Hugging Face
# Spaces 🔥
#
# > New sota single image-to-3D model from
# Stability AI
# > Generates point clouds as intermediate representation before producing the mesh. You can edit the point cloud to adjust the final mesh.
# > The Gradio app provides a simple point cloud editor, where you can drag, recolor and rescale the point clouds 🔥
# > The edited point cloud can then be uploaded to this demo to generate a new 3D model by checking the "Point cloud upload" box.
#
# 🤗 Useful
# Hugging Face
# and
# GitHub
# Links:
# > Spar3D model on 🔥Hub:
# https://lnkd.in/gFwzxHas
# > Launch the gradio app locally from their repo:
# https://lnkd.in/gtwXVaGq
# > SPAR3D gradio app on
# Hugging Face
# Spaces:
# https://lnkd.in/gf4-jUyK
# …more
# 432
# 17 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Moritz Laurer
# 🤗 Machine Learning Engineer
# 1w
# Report this post
# 🚀 Releasing a new zeroshot-classifier based on ModernBERT! Some key takeaways:
#
# - ⚡ Speed & efficiency: It's multiple times faster and uses significantly less memory than DeBERTav3. You can use larger batch sizes and enabling bf16 (instead of fp16) gave me a ~2x speed boost as well
# - 📉 Performance tradeoff: It performs slightly worse than DeBERTav3-zeroshot-v2 on average across my zeroshot classification task collection
# - 🧠 Use cases: I recommend using it for scenarios requiring speed and a larger context window (8k).
# - 💡 What’s next? I’m preparing a newer version trained on better + longer synthetic data to fully leverage the 8k context window and improve upon the training mix of my older zeroshot-v2.0 models. I also hope that there will be a multilingual variant in the future.
#
# Great work by @answerdotai!
# If you’re looking for a high-speed zeroshot classifier, give it a try!
#
# 📄 Resources below: 👇
# 478
# 10 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Joffrey THOMAS
# Machine Learning Engineer - Hugging Face 🤗
# 4d
# Report this post
# We are proud to partners in the next
# Mistral AI
# 𝐡𝐚𝐜𝐤𝐚𝐭𝐡𝐨𝐧 : 𝐆𝐚𝐦𝐞 𝐉𝐚𝐦 𝐞𝐝𝐢𝐭𝐢𝐨𝐧! 👾
# Over 100 participants will have 48h to build the best video game with AI. Each project must be playable and available online as
# Hugging Face
# 𝐬𝐩𝐚𝐜𝐞𝐬.🤗
#
# As a sponsor, we will provide mentorship (
# Thomas Simonini
# and myself) as well as credits to spend on compute or inference endpoints. 🚀
#
# 𝐖𝐡𝐞𝐧 ?  from Friday, January 24th to Sunday January 26th 2025
# 𝐖𝐡𝐞𝐫𝐞 ? in the heart of Paris, in the incredible offices of
# Photoroom
# 𝐇𝐨𝐰 𝐭𝐨 𝐚𝐩𝐩𝐥𝐲 ?  spots are limited, apply here before January 20th :
# https://lu.ma/2rsuklms
# Stay tuned & follow the
# spotlight paris
# account for surprise announcements!
#
# Co sponsors include:
# Entrepreneur First
# ,
# Photoroom
# ,
# ElevenLabs
# ,
# Scaleway
# ,
# Nebius
# ,
# Balderton Capital
# .
# 53
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 49,474 followers
# 4d
# Report this post
# 🥳 Gradio chatbot Assistants can now take in Audio inputs directly from your Microphone!🎙️🔥
#
# You just need to set sources=["microphone", "upload"] in gr.MultimodalTextbox. Attached demo showcases the feature using gpt-4o-audio-preview.
# …more
# 93
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 49,474 followers
# 5d
# Report this post
# 🔥Exciting New Feature: Load a chatbot from any OpenAI-API compatible endpoint in a single line of code 🤯
#
# If there is a chat server serving an OpenAI API compatible endpoint, spinning up your Chatbot is this easy:
# 𝚐𝚛.𝚕𝚘𝚊𝚍_𝚌𝚑𝚊𝚝("𝚑𝚝𝚝𝚙://𝚕𝚘𝚌𝚊𝚕𝚑𝚘𝚜𝚝:𝟷𝟷𝟺𝟹𝟺/𝚟𝟷/", 𝚖𝚘𝚍𝚎𝚕="𝚕𝚕𝚊𝚖𝚊𝟹.𝟸", 𝚝𝚘𝚔𝚎𝚗=𝙽𝚘𝚗𝚎).𝚕𝚊𝚞𝚗𝚌𝚑()
# …more
# 246
# 20 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Perplexity
# Software Development
# San Francisco, California
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Analyst jobs
# 694,057 open jobs
# Intelligence Specialist jobs
# 7,156 open jobs
# Manager jobs
# 1,880,925 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Director jobs
# 1,220,357 open jobs
# Associate jobs
# 1,091,945 open jobs
# Python Developer jobs
# 46,642 open jobs
# Evangelist jobs
# 5,068 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Quantitative Analyst jobs
# 19,570 open jobs
# Program Manager jobs
# 243,900 open jobs
# Data Science Specialist jobs
# 2,441 open jobs
# Lead Software Engineer jobs
# 68,215 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 7 total rounds
# Last Round
# Series D
# Feb 16, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Intern jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Scientist jobs
# Developer jobs
# Research Intern jobs
# Analyst jobs
# Intelligence Specialist jobs
# Quantitative Analyst jobs
# Technician jobs
# Data Science Specialist jobs
# Project Manager jobs
# Summer Intern jobs
# Manager jobs
# Senior Staff Engineer jobs
# PHD jobs
# Trader jobs
# Researcher jobs
# Data Scientist jobs
# Writer jobs
# Data Analyst jobs
# Product Designer jobs
# Back End Developer jobs
# Spring Intern jobs
# Program Manager jobs
# Technology Officer jobs
# Software Intern jobs
# Security Professional jobs
# Senior Software Engineer jobs
# Python Developer jobs
# Engineering Manager jobs
# Web Developer jobs
# Graduate jobs
# Full Stack Engineer jobs
# Professor jobs
# Head jobs
# Verification Manager jobs
# User Experience Designer jobs
# Recruiter jobs
# Chief Executive Officer jobs
# Associate jobs
# Support Developer jobs
# Senior Firmware Engineer jobs
# Marketing Manager jobs
# Modeling Engineer jobs
# Designer jobs
# Automation Lead jobs
# Options Trader jobs
# Agile Coach jobs
# Research Engineer jobs
# Software Quality Assurance Analyst jobs
# User Experience Manager jobs
# Technical Intern jobs
# Junior Network Engineer jobs
# Information Technology Recruiter jobs
# User Researcher jobs
# Player jobs
# Engineering Project Manager jobs
# Digital Strategist jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'join page', 'url': 'https://huggingface.co/join'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nNEW\nsmolagents - a smol library to build great agents\nUse models from the HF Hub in LM Studio\nUse Ollama with GGUF Models from the HF Hub\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nTrending on\nthis week\nModels\nmicrosoft/phi-4\nUpdated\n5 days ago\n•\n49.9k\n•\n1.12k\nhexgrad/Kokoro-82M\nUpdated\n7 days ago\n•\n11.4k\n•\n911\ndeepseek-ai/DeepSeek-V3\nUpdated\n15 days ago\n•\n115k\n•\n1.76k\nNovaSky-AI/Sky-T1-32B-Preview\nUpdated\nabout 9 hours ago\n•\n652\n•\n220\nblack-forest-labs/FLUX.1-dev\nUpdated\nAug 16, 2024\n•\n1.26M\n•\n7.96k\nBrowse 400k+ models\nSpaces\nRunning\non\nZero\n2.91k\n🏢\nTRELLIS\nScalable and Versatile 3D Generation from images\nRunning\non\nZero\n1.57k\n📈\nIC Light V2\nRunning\non\nZero\n390\n❤️\nKokoro TTS\nNow in 5 languages!\nRunning\n357\n📈\n2024 AI Timeline\nRunning\non\nL4\n228\n👄\nLatentSync\nAudio Conditioned LipSync with Latent Diffusion Models\nBrowse 150k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\n8 days ago\n•\n5.12k\n•\n6.84k\nDAMO-NLP-SG/multimodal_textbook\nUpdated\n2 days ago\n•\n5.31k\n•\n89\ncfahlgren1/react-code-instructions\nUpdated\nabout 1 hour ago\n•\n678\n•\n112\nNovaSky-AI/Sky-T1_data_17k\nUpdated\nabout 9 hours ago\n•\n278\n•\n47\nPowerInfer/QWQ-LONGCOT-500K\nUpdated\n18 days ago\n•\n838\n•\n101\nBrowse 100k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n378 models\n•\n1.89k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.06k models\n•\n4.1k followers\nAmazon Web Services\ncompany\n•\n21 models\n•\n2.52k followers\nGoogle\ncompany\n•\n913 models\n•\n6.45k followers\nIntel\ncompany\n•\n217 models\n•\n2.14k followers\nMicrosoft\ncompany\n•\n353 models\n•\n7.13k followers\nGrammarly\ncompany\n•\n10 models\n•\n109 followers\nWriter\nEnterprise\ncompany\n•\n17 models\n•\n197 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n137,511\nState-of-the-art ML for Pytorch, TensorFlow, and JAX.\nDiffusers\n27,093\nState-of-the-art diffusion models for image and audio generation in PyTorch.\nSafetensors\n3,002\nSimple, safe way to store and distribute neural networks weights safely and quickly.\nHub Python Library\n2,220\nClient library for the HF Hub: manage repositories from your Python runtime.\nTokenizers\n9,247\nFast tokenizers, optimized for both research and production.\nPEFT\n16,952\nParameter efficient finetuning methods for large models.\nTransformers.js\n12,572\nState-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.\ntimm\n32, ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.com/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Company Brochure
#
# ## Introducing Hugging Face
# Hugging Face is the leading AI community dedicated to building the future of machine learning. Our platform fosters collaboration among enthusiasts, professionals, and enterprises in the AI landscape, offering a wide range of models, datasets, and applications.
#
# ---
#
# ## Our Products
# - **Models**: Over 400,000 AI models available for various applications, including natural language processing, image recognition, and more.
# - **Datasets**: Access to 100,000+ datasets to fuel your AI projects.
# - **Spaces**: Discover a plethora of applications designed for diverse purposes, enabling open teamwork and knowledge sharing.
# - **Enterprise Solutions**: Tailored support for companies with dedicated security, access controls, and priority assistance.
#
# ---
#
# ## Customer Base
# More than **50,000 organizations** utilize Hugging Face in their operations, including industry giants such as:
# - **Google**
# - **Microsoft**
# - **Amazon Web Services**
# - **Meta**
# - **Intel**
#
# Join a community that encourages innovation and collaboration across multiple sectors.
#
# ---
#
# ## Company Culture
# At Hugging Face, we believe in openness, community engagement, and pushing the boundaries of what's possible with AI. We actively nurture a creative environment where:
# - Everyone is encouraged to share ideas and collaborate.
# - Continuous learning and professional development are prioritized.
# - Employees can build their portfolios and showcase their work on a global platform.
#
# ---
#
# ## Careers at Hugging Face
# Join our passionate team of innovators! We welcome talented individuals from diverse backgrounds who are eager to shape the future of AI. Available positions span various fields, including:
# - Machine Learning Engineering
# - Data Science
# - Community Management
# - Software Development
# - Product Management
#
# Explore career opportunities on our [Jobs Page](https://huggingface.co/jobs).
#
# ---
#
# ## Join the Movement
# Discover, learn, and grow with Hugging Face. Whether you're a seasoned professional, a budding enthusiast, or a business looking for enterprise solutions, we invite you to join our community and be part of the AI revolution.
#
# For more information, visit us at [Hugging Face](https://huggingface.co).
#
# ---
#
# **Hugging Face: Together, we build the future of AI.**

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}]}
# # Hugging Face Company Brochure
#
# ## Welcome to Hugging Face
#
# ### About Us
# Hugging Face is at the forefront of the artificial intelligence (AI) revolution, creating a collaborative platform for the machine learning community. Our mission is to democratize AI and machine learning by providing tools and resources that empower developers and researchers to innovate and build a better future.
#
# ### What We Offer
# - **Models**: Explore over 400,000 models, including state-of-the-art solutions for natural language processing, computer vision, and other modalities.
# - **Datasets**: Access to a vast library of 100,000+ datasets to enhance your machine learning projects.
# - **Spaces**: Host and collaborate on applications seamlessly, allowing for real-time innovation.
# - **Enterprise Solutions**: Tailored services for businesses including optimized inference endpoints, enterprise-grade security, and dedicated support.
#
# ### Our Community
# More than 50,000 organizations trust Hugging Face, including notable tech leaders such as Google, Microsoft, and Amazon Web Services. Our platform enables companies to leverage collective knowledge and contribute back to the community, fostering growth and collaboration.
#
# ### Culture & Values
# At Hugging Face, we believe in the power of open-source technology and community collaboration. Our culture is centered around:
# - **Innovation**: We encourage creative thinking and experimentation.
# - **Inclusivity**: We are committed to building a diverse and welcoming environment.
# - **Empowerment**: We provide our users with the tools and resources they need to succeed.
#
# ### Careers at Hugging Face
# Join a team that is passionate about AI and machine learning! We are on the lookout for talented individuals who are eager to contribute to cutting-edge technology. If you’re interested in being part of a supportive community that values your input and growth, check out our [careers page](https://huggingface.co/jobs).
#
# ### Why Choose Hugging Face?
# - **Community Focused**: Be part of a thriving community of thinkers, creators, and developers.
# - **Open Source Commitment**: We believe in sharing knowledge and tools to advance machine learning collectively.
# - **Comprehensive Support**: From learning resources to enterprise-level assistance, we support our users at every stage.
#
# ### Get Involved!
# Whether you are a developer, researcher, or business leader, Hugging Face offers tools and resources tailored to your needs. Explore our platform, contribute to open-source projects, and join us in building the future of AI.
#
# For more information, visit our website at [Hugging Face](https://huggingface.co) and sign up to start your journey with us today!
#
# ---
#
# **Contact Us**:
# Email: support@huggingface.co
# Follow us on: [Twitter](https://twitter.com/huggingface), [LinkedIn](https://linkedin.com/company/huggingface)

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
